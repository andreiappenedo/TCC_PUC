# %%
import pandas as pd
import numpy as np

# %%
## Importar a base do Primeiro Trimestre de 2021 ##
primeiroTri2021 = pd.read_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\arquivo_lai_FGTS_MG_202103.csv', sep=';', parse_dates=True, encoding='iso-8859-1')
primeiroTri2021.shape

# Remove duplicadas
primeiroTri2021 = primeiroTri2021.drop_duplicates()

# %%
## Adiciona coluna para identificar o período do dataframe ##
primeiroTri2021.insert(0, "PERIODO", '01/01/2021', True)
primeiroTri2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32244 entries, 0 to 32243
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIODO                  32244 non-null  object
#  1   CPF_CNPJ                 32244 non-null  object
#  2   TIPO_PESSOA              32244 non-null  object
#  3   TIPO_DEVEDOR             32244 non-null  object
#  4   NOME_DEVEDOR             32244 non-null  object
#  5   UF_UNIDADE_RESPONSAVEL   32244 non-null  object
#  6   UNIDADE_RESPONSAVEL      32244 non-null  object
#  7   ENTIDADE_RESPONSAVEL     32244 non-null  object
#  8   UNIDADE_INSCRICAO        32244 non-null  object
#  9   NUMERO_INSCRICAO         32244 non-null  object
#  10  TIPO_SITUACAO_INSCRICAO  32244 non-null  object
#  11  SITUACAO_INSCRICAO       32244 non-null  object
#  12  RECEITA_PRINCIPAL        32244 non-null  object
#  13  DATA_INSCRICAO           32244 non-null  object
#  14  INDICADOR_AJUIZADO       32244 non-null  object
#  15  VALOR_CONSOLIDADO        32244 non-null  float64
# dtypes: float64(1), object(15)
# memory usage: 4.2+ MB

# %%
primeiroTri2021.head()
# Out:
#       PERIODO            CPF_CNPJ      TIPO_PESSOA TIPO_DEVEDOR  \
# 0  01/01/2021  06.286.147/0001-76  Pessoa jurídica    Principal
# 1  01/01/2021  06.286.147/0001-76  Pessoa jurídica    Principal
# 2  01/01/2021  17.268.863/0001-47  Pessoa jurídica    Principal
# 3  01/01/2021  19.376.161/0001-02  Pessoa jurídica    Principal
# 4  01/01/2021  05.517.165/0001-59  Pessoa jurídica    Principal
#
#                                         NOME_DEVEDOR UF_UNIDADE_RESPONSAVEL  \
# 0            ART BRINDES INDUSTRIA E COMERCIO EIRELI                     MG
# 1            ART BRINDES INDUSTRIA E COMERCIO EIRELI                     MG
# 2                          JOAQUIM GERVASIO COUTINHO                     MG
# 3  HMAXX INDUSTRIA E COMERCIO DE ALIMENTOS E ADOC...                     MG
# 4                             ANDREA DA SILVA VIEIRA                     MG
#
#   UNIDADE_RESPONSAVEL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO NUMERO_INSCRICAO  \
# 0             UBERABA                 PGFN           UBERABA    CSMG201901085
# 1             UBERABA                 PGFN           UBERABA    FGMG202100105
# 2        MINAS GERAIS                 PGFN      MINAS GERAIS    FGBH000083351
# 3        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201902652
# 4        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201500294
#
#   TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO           RECEITA_PRINCIPAL  \
# 0             Em cobrança           AJUIZADA  Contribuições LC110 (FGTS)
# 1             Em cobrança           INSCRITA          Contribuições FGTS
# 2             Em cobrança           AJUIZADA          Contribuições FGTS
# 3             Em cobrança           INSCRITA          Contribuições FGTS
# 4             Em cobrança           INSCRITA          Contribuições FGTS
#
#   DATA_INSCRICAO INDICADOR_AJUIZADO  VALOR_CONSOLIDADO
# 0     05/06/2019                SIM            2291.91
# 1     03/02/2021                NAO           66986.07
# 2     05/08/1983                SIM            6354.85
# 3     05/11/2019                NAO           12820.18
# 4     04/02/2015                NAO           12053.58

# %%
## Importar a base do Segundo Trimestre de 2021 ##
segundoTri2021 = pd.read_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\arquivo_lai_FGTS_MG_202106.csv', sep=';', parse_dates=True, encoding='iso-8859-1')
segundoTri2021.shape
segundoTri2021 = segundoTri2021.drop_duplicates()

# %%
## Adiciona coluna para identificar o período do dataframe ##
segundoTri2021.insert(0, "PERIODO", '01/04/2021', True)
segundoTri2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32728 entries, 0 to 32727
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIODO                  32728 non-null  object
#  1   CPF_CNPJ                 32728 non-null  object
#  2   TIPO_PESSOA              32728 non-null  object
#  3   TIPO_DEVEDOR             32728 non-null  object
#  4   NOME_DEVEDOR             32728 non-null  object
#  5   UF_UNIDADE_RESPONSAVEL   32728 non-null  object
#  6   UNIDADE_RESPONSAVEL      32728 non-null  object
#  7   ENTIDADE_RESPONSAVEL     32728 non-null  object
#  8   UNIDADE_INSCRICAO        32728 non-null  object
#  9   NUMERO_INSCRICAO         32728 non-null  object
#  10  TIPO_SITUACAO_INSCRICAO  32728 non-null  object
#  11  SITUACAO_INSCRICAO       32728 non-null  object
#  12  RECEITA_PRINCIPAL        32728 non-null  object
#  13  DATA_INSCRICAO           32728 non-null  object
#  14  INDICADOR_AJUIZADO       32728 non-null  object
#  15  VALOR_CONSOLIDADO        32728 non-null  float64
# dtypes: float64(1), object(15)
# memory usage: 4.2+ MB

# %%
segundoTri2021.head()
# Out:
#       PERIODO            CPF_CNPJ      TIPO_PESSOA TIPO_DEVEDOR  \
# 0  01/04/2021  22.905.919/0001-67  Pessoa jurídica    Principal
# 1  01/04/2021  08.283.338/0001-00  Pessoa jurídica    Principal
# 2  01/04/2021  07.558.788/0001-03  Pessoa jurídica    Principal
# 3  01/04/2021  07.558.788/0001-03  Pessoa jurídica    Principal
# 4  01/04/2021  07.558.788/0001-03  Pessoa jurídica    Principal
#
#                                         NOME_DEVEDOR UF_UNIDADE_RESPONSAVEL  \
# 0                                  FUJI LANCHES LTDA                     MG
# 1  INNOVATIS COMERCIO DE EQUIPAMENTOS DE PRECISAO...                     MG
# 2                       DROGARIA SOUZA & SOARES LTDA                     MG
# 3                       DROGARIA SOUZA & SOARES LTDA                     MG
# 4                       DROGARIA SOUZA & SOARES LTDA                     MG
#
#   UNIDADE_RESPONSAVEL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO NUMERO_INSCRICAO  \
# 0        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201901143
# 1        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201801754
# 2        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201701719
# 3        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201701717
# 4        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG201701718
#
#   TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO           RECEITA_PRINCIPAL  \
# 0             Em cobrança           INSCRITA          Contribuições FGTS
# 1             Em cobrança           INSCRITA          Contribuições FGTS
# 2             Em cobrança           INSCRITA          Contribuições FGTS
# 3             Em cobrança           INSCRITA          Contribuições FGTS
# 4             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
#
#   DATA_INSCRICAO INDICADOR_AJUIZADO  VALOR_CONSOLIDADO
# 0     06/06/2019                NAO            4088.31
# 1     21/11/2018                NAO           16839.59
# 2     11/05/2017                NAO            8020.96
# 3     11/05/2017                NAO            1540.68
# 4     11/05/2017                NAO            2100.71

# %%
## Importar a base do Terceiro Trimestre de 2021 ##
terceiroTri2021 = pd.read_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\arquivo_lai_FGTS_MG_202109.csv', sep=';', parse_dates=True, encoding='iso-8859-1')
terceiroTri2021.shape
terceiroTri2021 = terceiroTri2021.drop_duplicates()

# %%
## Adiciona coluna para identificar o período do dataframe ##
terceiroTri2021.insert(0, "PERIODO", '01/07/2021', True)
terceiroTri2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28181 entries, 0 to 28180
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIODO                  28181 non-null  object
#  1   CPF_CNPJ                 28181 non-null  object
#  2   TIPO_PESSOA              28181 non-null  object
#  3   TIPO_DEVEDOR             28181 non-null  object
#  4   NOME_DEVEDOR             28181 non-null  object
#  5   UF_UNIDADE_RESPONSAVEL   28181 non-null  object
#  6   UNIDADE_RESPONSAVEL      28181 non-null  object
#  7   ENTIDADE_RESPONSAVEL     28181 non-null  object
#  8   UNIDADE_INSCRICAO        28181 non-null  object
#  9   NUMERO_INSCRICAO         28181 non-null  object
#  10  TIPO_SITUACAO_INSCRICAO  28181 non-null  object
#  11  SITUACAO_INSCRICAO       28181 non-null  object
#  12  RECEITA_PRINCIPAL        28181 non-null  object
#  13  DATA_INSCRICAO           28181 non-null  object
#  14  INDICADOR_AJUIZADO       28181 non-null  object
#  15  VALOR_CONSOLIDADO        28181 non-null  float64
# dtypes: float64(1), object(15)
# memory usage: 3.7+ MB

# %%
terceiroTri2021.head()
# Out:
#       PERIODO            CPF_CNPJ      TIPO_PESSOA TIPO_DEVEDOR  \
# 0  01/07/2021  03.200.004/0001-01  Pessoa jurídica    Principal
# 1  01/07/2021  02.878.024/0001-73  Pessoa jurídica    Principal
# 2  01/07/2021  02.199.633/0001-04  Pessoa jurídica    Principal
# 3  01/07/2021  05.150.371/0001-73  Pessoa jurídica    Principal
# 4  01/07/2021  26.040.998/0001-41  Pessoa jurídica    Principal
#
#                                  NOME_DEVEDOR UF_UNIDADE_RESPONSAVEL  \
# 0          CONDOMINIO ESPECIAL BAHIA SHOPPING                     MG
# 1  LAVANDERIA E MIX DE SERVICOS GENESIS LTDA.                     MG
# 2                      JOSE RAGI CHEIRI FILHO                     MG
# 3                     BRITO ANTIGUIDADES LTDA                     MG
# 4                        ELETRICA VIMAZA LTDA                     MG
#
#   UNIDADE_RESPONSAVEL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO NUMERO_INSCRICAO  \
# 0        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200700070
# 1        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200700175
# 2        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200701388
# 3        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200900949
# 4        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200901161
#
#   TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO           RECEITA_PRINCIPAL  \
# 0             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
# 1             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
# 2             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
# 3             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
# 4             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
#
#   DATA_INSCRICAO INDICADOR_AJUIZADO  VALOR_CONSOLIDADO
# 0     11/04/2007                NAO             349.47
# 1     07/05/2007                NAO             192.47
# 2     25/09/2007                NAO            1254.92
# 3     24/04/2009                NAO             371.74
# 4     05/06/2009                NAO             956.68

# %%
## Importar a base do Quarto Trimestre de 2021 ##
quartoTri2021 = pd.read_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\arquivo_lai_FGTS_MG_202112.csv', sep=';', parse_dates=True, encoding='iso-8859-1')
quartoTri2021.shape
quartoTri2021 = quartoTri2021.drop_duplicates()

# %%
## Adiciona coluna para identificar o período do dataframe ##
quartoTri2021.insert(0, "PERIODO", '01/10/2021', True)
quartoTri2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28022 entries, 0 to 28021
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIODO                  28022 non-null  object
#  1   CPF_CNPJ                 28022 non-null  object
#  2   TIPO_PESSOA              28022 non-null  object
#  3   TIPO_DEVEDOR             28022 non-null  object
#  4   NOME_DEVEDOR             28022 non-null  object
#  5   UF_UNIDADE_RESPONSAVEL   28022 non-null  object
#  6   UNIDADE_RESPONSAVEL      28022 non-null  object
#  7   ENTIDADE_RESPONSAVEL     28022 non-null  object
#  8   UNIDADE_INSCRICAO        28022 non-null  object
#  9   NUMERO_INSCRICAO         28022 non-null  object
#  10  TIPO_SITUACAO_INSCRICAO  28022 non-null  object
#  11  SITUACAO_INSCRICAO       28022 non-null  object
#  12  RECEITA_PRINCIPAL        28022 non-null  object
#  13  DATA_INSCRICAO           28022 non-null  object
#  14  INDICADOR_AJUIZADO       28022 non-null  object
#  15  VALOR_CONSOLIDADO        28022 non-null  float64
# dtypes: float64(1), object(15)
# memory usage: 3.6+ MB

# %%
quartoTri2021.head()
# Out:
#       PERIODO            CPF_CNPJ      TIPO_PESSOA TIPO_DEVEDOR  \
# 0  01/10/2021  05.667.429/0001-50  Pessoa jurídica    Principal
# 1  01/10/2021  20.935.243/0001-29  Pessoa jurídica    Principal
# 2  01/10/2021  20.935.243/0001-29  Pessoa jurídica    Principal
# 3  01/10/2021  20.935.243/0001-29  Pessoa jurídica    Principal
# 4  01/10/2021  19.715.457/0001-00  Pessoa jurídica    Principal
#
#                              NOME_DEVEDOR UF_UNIDADE_RESPONSAVEL  \
# 0  CEPAC  CENTRAL PAULISTA DE COUROS LTDA                     MG
# 1  MASSA FALIDA DE AGUIA TRANSPORTES LTDA                     MG
# 2  MASSA FALIDA DE AGUIA TRANSPORTES LTDA                     MG
# 3  MASSA FALIDA DE AGUIA TRANSPORTES LTDA                     MG
# 4             CONDOMINIO EDIFICIO ACAIACA                     MG
#
#   UNIDADE_RESPONSAVEL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO NUMERO_INSCRICAO  \
# 0        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG201701442
# 1        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG200700291
# 2        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG200700292
# 3        MINAS GERAIS                 PGFN      MINAS GERAIS    FGMG200802652
# 4        MINAS GERAIS                 PGFN      MINAS GERAIS    CSMG202000419
#
#   TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO           RECEITA_PRINCIPAL  \
# 0             Em cobrança           AJUIZADA          Contribuições FGTS
# 1             Em cobrança           AJUIZADA          Contribuições FGTS
# 2             Em cobrança           AJUIZADA  Contribuições LC110 (FGTS)
# 3             Em cobrança           AJUIZADA          Contribuições FGTS
# 4             Em cobrança           INSCRITA  Contribuições LC110 (FGTS)
#
#   DATA_INSCRICAO INDICADOR_AJUIZADO  VALOR_CONSOLIDADO
# 0     24/04/2017                SIM           16480.88
# 1     21/05/2007                SIM           34668.23
# 2     21/05/2007                SIM            2363.84
# 3     25/09/2008                SIM             259.17
# 4     28/02/2020                NAO            1806.25

# %%
## Concatena os 4 períodos em um único dataframe ##
consolidado = pd.concat([primeiroTri2021, segundoTri2021, terceiroTri2021, quartoTri2021])

# %%
## Exporta para csv para trabalharmos a análise dos dados ##
consolidado.to_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\Consolidado2021.csv', sep=';', index=False, encoding='iso-8859-1')
