# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Importando a base Consolidada
dividasMG = pd.read_csv(r'O:\OneDrive\ANDREIA\MATERIAL_ESTUDOS\PUC\TCC\Datasets\Consolidado2021.csv', sep=';', parse_dates=True, encoding='iso-8859-1')

# %%
dividasMG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121175 entries, 0 to 121174
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   PERIODO                  121175 non-null  object
#  1   CPF_CNPJ                 121175 non-null  object
#  2   TIPO_PESSOA              121175 non-null  object
#  3   TIPO_DEVEDOR             121175 non-null  object
#  4   NOME_DEVEDOR             121175 non-null  object
#  5   UF_UNIDADE_RESPONSAVEL   121175 non-null  object
#  6   UNIDADE_RESPONSAVEL      121175 non-null  object
#  7   ENTIDADE_RESPONSAVEL     121175 non-null  object
#  8   UNIDADE_INSCRICAO        121175 non-null  object
#  9   NUMERO_INSCRICAO         121175 non-null  object
#  10  TIPO_SITUACAO_INSCRICAO  121175 non-null  object
#  11  SITUACAO_INSCRICAO       121175 non-null  object
#  12  RECEITA_PRINCIPAL        121175 non-null  object
#  13  DATA_INSCRICAO           121175 non-null  object
#  14  INDICADOR_AJUIZADO       121175 non-null  object
#  15  VALOR_CONSOLIDADO        121175 non-null  float64
# dtypes: float64(1), object(15)
# memory usage: 14.8+ MB

# %%
## Somar as dividas por periodo
dividasMG.groupby('PERIODO')['VALOR_CONSOLIDADO'].sum().plot.bar()

plt.xlabel('Período - Trimestre')
plt.ylabel('Total')

## Os valores são representados na ordem de milhão
print(dividasMG.groupby('PERIODO')['VALOR_CONSOLIDADO'].sum())
# Out:
# PERIODO
# 01/01/2021    1.902615e+09
# 01/04/2021    2.028318e+09
# 01/07/2021    2.101908e+09
# 01/10/2021    2.115273e+09
# Name: VALOR_CONSOLIDADO, dtype: float64

# %%
## Total por TIPO_PESSOA
dividasMG.TIPO_PESSOA.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, startangle=60)
# Out:
# <Axes: ylabel='TIPO_PESSOA'>

# %%
## Total da divida por TIPO_PESSOA, para saber se pessoa juridica ou fisica deve mais
dividasMG.groupby('TIPO_PESSOA')['VALOR_CONSOLIDADO'].sum().plot.bar()
plt.xlabel('Tipo Pessoa')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
## Total por UNIDADE_RESPONSAVEL
dividasMG.UNIDADE_RESPONSAVEL.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, startangle=60)
# Out:
# <Axes: ylabel='UNIDADE_RESPONSAVEL'>

# %%
## Total da divida por UNIDADE_RESPONSAVEL
dividasMG.groupby('UNIDADE_RESPONSAVEL')['VALOR_CONSOLIDADO'].sum().plot.bar()

plt.xlabel('Região')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
## Total por TIPO_SITUACAO_INSCRICAO
dividasMG.TIPO_SITUACAO_INSCRICAO.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, startangle=20)
# Out:
# <Axes: ylabel='TIPO_SITUACAO_INSCRICAO'>

# %%
## Total da divida por TIPO_SITUACAO_INSCRICAO
dividasMG.groupby('TIPO_SITUACAO_INSCRICAO')['VALOR_CONSOLIDADO'].sum().plot.bar()

plt.xlabel('Tipo da Situação da Inscrição')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
## Total por SITUACAO_INSCRICAO
dividasMG.SITUACAO_INSCRICAO.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, startangle=20)
# Out:
# <Axes: ylabel='SITUACAO_INSCRICAO'>

# %%
## Total da divida por SITUACAO_INSCRICAO
dividasMG.groupby('SITUACAO_INSCRICAO')['VALOR_CONSOLIDADO'].sum().plot.bar()

plt.xlabel('Situação da Inscrição')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
## Total por RECEITA_PRINCIPAL
dividasMG.RECEITA_PRINCIPAL.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, startangle=20)
# Out:
# <Axes: ylabel='RECEITA_PRINCIPAL'>

# %%
## Total por INDICADOR_AJUIZADO
dividasMG.groupby('INDICADOR_AJUIZADO')['VALOR_CONSOLIDADO'].sum().plot.bar()

plt.xlabel('Indicador Ajuizado')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')
